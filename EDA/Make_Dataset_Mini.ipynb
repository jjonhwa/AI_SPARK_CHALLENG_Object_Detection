# %% [markdown]
# ## Make Mini Dataset
# - HyperParameter Search를 위해 Dataset을 작게 sampling한다.
# - MultiLabelStratified를 활용하여 Box의 개수와 class의 비율을 유지하면서 sampling한다.

# %%
from tqdm import tqdm
from glob import glob

import pandas as pd
import numpy as np
import json
import math
import os
import random

# %%
# !pip install iterative-stratification
# Out:
# Collecting iterative-stratification
#   Downloading iterative_stratification-0.1.7-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from iterative-stratification) (1.19.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from iterative-stratification) (1.4.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from iterative-stratification) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->iterative-stratification) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->iterative-stratification) (3.1.0)
# Installing collected packages: iterative-stratification
# Successfully installed iterative-stratification-0.1.7

# %%
# Google Drive mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
if not os.path.exists('data'):
    os.mkdir('data')
if not os.path.exists('data/Training'):
    os.mkdir('data/Training')

# %%
# !unzip -q /content/drive/MyDrive/AI_Factory_가축/Training/[원천]돼지_bbox.zip -d /content/data/Training/pig_image
# !unzip -q /content/drive/MyDrive/AI_Factory_가축/Training/[원천]소_bbox.zip -d /content/data/Training/cow_image

# !unzip -q /content/drive/MyDrive/AI_Factory_가축/Training/[라벨]돼지_bbox.zip -d /content/data/Training/pig_label
# !unzip -q /content/drive/MyDrive/AI_Factory_가축/Training/[라벨]소_bbox.zip -d /content/data/Training/cow_label

# %%
train_pig_image = glob('/content/data/Training/pig_image/*.jpg')
train_cow_image = glob('/content/data/Training/cow_image/*.jpg')
train_pig_label = glob('/content/data/Training/pig_label/*.json')
train_cow_label = glob('/content/data/Training/cow_label/*.json')

train_pig_label.sort()
train_pig_image.sort()
train_cow_label.sort()
train_cow_image.sort()

# %% [markdown]
# ### MultiLableSplited Dataset 만들기 (ver. mini)

# %%
total_image = train_pig_image + train_cow_image
total_label = train_pig_label + train_cow_label

# %%
data = pd.DataFrame([x for x in zip(total_image, total_label)])
data.rename(columns = {0 : 'image',
                       1 : 'label'}, 
            inplace = True)

# %% [markdown]
# #### One-Hot Encoding
# - pig/cow
# - little/medium/many

# %%
def box_count_pig(num):
    """
    돼지 이미지에서 가지고 있는 Box의 수를 기준으로 Pig Dataset을 분류한다.
    Args: 
        num: bounding box의 개수
    Return:
        "little" - bounding box의 개수가 8개 미만일 경우
        "medium" - bounding box의 개수가 8~13일 경우
        "many" - bounding box의 개수가 13이상일 경우
    """

    if num < 8:
        return 'little'
    elif num < 13:
        return 'medium'
    else:
        return 'many'

def box_count_cow(num):
    """
    소 이미지에서 가지고 있는 Box의 수를 기준으로 Pig Dataset을 분류한다.
    Args: 
        num: bounding box의 개수
    Return:
        "little" - bounding box의 개수가 4개 미만일 경우
        "medium" - bounding box의 개수가 4~6일 경우
        "many" - bounding box의 개수가 6이상일 경우
    """
    if num < 4:
        return 'little'
    if num < 6:
        return 'medium'
    else:
        return 'many'

# %%
cow = []
pig = []
many = []
medium = []
little = []
for i in range(len(data)):
    label = data['label'][i]
    with open(label, 'r') as f:
        label_data = json.load(f)

    # cow인지 pig인지 list에 담기
    if 'cow' in data['label'][i]:
        cow.append(1)
        pig.append(0)
    else:
        pig.append(1)
        cow.append(0)

    # Box의 개수에 따라 many, medium, little의 list에 담기
    box_info = label_data['label_info']['annotations']
    box_count = len(box_info)

    if 'cow' in data['label'][i]:
        count = box_count_cow(box_count)
        if count == 'little':
            little.append(1)
            many.append(0)
            medium.append(0)
        elif count == 'medium':
            little.append(0)
            many.append(1)
            medium.append(0)
        else:
            little.append(0)
            many.append(0)
            medium.append(1)
    else:
        count = box_count_pig(box_count)
        if count == 'little':
            little.append(1)
            many.append(0)
            medium.append(0)
        elif count == 'medium':
            little.append(0)
            many.append(1)
            medium.append(0)
        else:
            little.append(0)
            many.append(0)
            medium.append(1)

# %%
data['cow'] = cow
data['pig'] = pig
data['little'] = little
data['many'] = many
data['medium'] = medium

# %%
data.head()
# Out:
#                                                image  ... medium
# 0  /content/data/Training/pig_image/livestock_pig...  ...      1
# 1  /content/data/Training/pig_image/livestock_pig...  ...      0
# 2  /content/data/Training/pig_image/livestock_pig...  ...      1
# 3  /content/data/Training/pig_image/livestock_pig...  ...      1
# 4  /content/data/Training/pig_image/livestock_pig...  ...      0
#
# [5 rows x 7 columns]

# %% [markdown]
# #### Dataset 나누기

# %%
X = data['image'].to_numpy()
Y = data[['cow', 'pig', 'little', 'many', 'medium']].to_numpy(dtype=np.float32)

# %%
# 마지막 "KFold Stacking을 활용하여 YOLO학습하기"에 사용
from iterstrat.ml_stratifiers import MultilabelStratifiedKFold

mlsk = MultilabelStratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# 첫번째, 두번째 KFold에서의 Valid Dataset을 mini Train Dataset으로 활용
# 마지막 KFold에서의 Valid Dataset을 mini Valid Dataset으로 활용
for i, (train_index, valid_index) in enumerate(mlsk.split(X, Y)):
    if i == 0 :
        _, tmp_train_x1 = X[train_index], X[valid_index]
        _, tmp_train_y1 = Y[train_index], Y[valid_index]
    if i == 1:
        _, tmp_train_x2 = X[train_index], X[valid_index]
        _, tmp_train_y2 = Y[train_index], Y[valid_index]
    X_train, X_valid = X[train_index], X[valid_index]
    y_train, y_valid = Y[train_index], Y[valid_index]

# %%
print(len(tmp_train_x1))
print(len(tmp_train_x2))

# 겹치는 Dataset이 있는지 확인
print(len(set(tmp_train_x1) & set(tmp_train_x2) & set(X_valid)))
# Out:
# 3291
# 3291
# 0

# %%
X_train = list(tmp_train_x1) + list(tmp_train_x2)
y_train = list(tmp_train_y1) + list(tmp_train_y2)
print("Mini Train Dataset의 image의 개수:", len(X_train))
print("Mini Train Dataset의 label의 개수:", len(y_train))
# Out:
# Mini Train Dataset의 image의 개수: 6582
# Mini Train Dataset의 label의 개수: 6582

# %% [markdown]
# #### 나누어진 Dataset 확인

# %%
train_pig_count = 0
train_cow_count = 0
train_cow_many_count = 0
train_cow_medium_count = 0
train_cow_little_count = 0
train_pig_many_count = 0
train_pig_medium_count = 0
train_pig_little_count = 0

for y in y_train:
    if y[0] == 0.:
        train_pig_count += 1
        if y[2] == 1:
            train_pig_little_count += 1
        elif y[3] == 1:
            train_pig_many_count += 1
        elif y[4] == 1:
            train_pig_medium_count += 1
    elif y[0] == 1.:
        train_cow_count += 1
        if y[2] == 1:
            train_cow_little_count += 1
        elif y[3] == 1:
            train_cow_many_count += 1
        elif y[4] == 1:
            train_cow_medium_count += 1

# %%
print("소  : KFold 전 -> many", len(data[data['cow'] == 1][data['many'] == 1]))
print("소  : KFold 전 -> little", len(data[data['cow'] == 1][data['little'] == 1]))
print("소  : KFold 전 -> medium", len(data[data['cow'] == 1][data['medium'] == 1]))
print()
print("소  : KFold 후 -> many", train_cow_many_count)
print("소  : KFold 후 -> little", train_cow_little_count)
print("소  : KFold 후 -> medium", train_cow_medium_count)
print()
print("돼지: KFold 전 -> many", len(data[data['pig'] == 1][data['many'] == 1]))
print("돼지: KFold 전 -> little", len(data[data['pig'] == 1][data['little'] == 1]))
print("돼지: KFold 전 -> medium", len(data[data['pig'] == 1][data['medium'] == 1]))
print()
print("돼지: KFold 후 -> many", train_pig_many_count)
print("돼지: KFold 후 -> little", train_pig_little_count)
print("돼지: KFold 후 -> medium", train_pig_medium_count)
# Out:
# 소  : KFold 전 -> many 3413
# 소  : KFold 전 -> little 7383
# 소  : KFold 전 -> medium 1356
#
# 소  : KFold 후 -> many 1388
# 소  : KFold 후 -> little 2936
# 소  : KFold 후 -> medium 537
#
# 돼지: KFold 전 -> many 2749
# 돼지: KFold 전 -> little 506
# 돼지: KFold 전 -> medium 1048
#
# 돼지: KFold 후 -> many 1076
# 돼지: KFold 후 -> little 220
# 돼지: KFold 후 -> medium 425
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   # This is added back by InteractiveShellApp.init_path()

# %% [markdown]
# ### 사용할 Dataset 만들기

# %%
if not os.path.exists('mini_data'):
    os.mkdir('mini_data')
if not os.path.exists('mini_data/Training'):
    os.mkdir('mini_data/Training')
if not os.path.exists('mini_data/Training/cow_image'):
    os.mkdir('mini_data/Training/cow_image')
if not os.path.exists('mini_data/Training/cow_label'):
    os.mkdir('mini_data/Training/cow_label')
if not os.path.exists('mini_data/Training/pig_image'):
    os.mkdir('mini_data/Training/pig_image')
if not os.path.exists('mini_data/Training/pig_label'):
    os.mkdir('mini_data/Training/pig_label')
if not os.path.exists('mini_data/Validation'):
    os.mkdir('mini_data/Validation')
if not os.path.exists('mini_data/Validation/cow_image'):
    os.mkdir('mini_data/Validation/cow_image')
if not os.path.exists('mini_data/Validation/cow_label'):
    os.mkdir('mini_data/Validation/cow_label')
if not os.path.exists('mini_data/Validation/pig_image'):
    os.mkdir('mini_data/Validation/pig_image')
if not os.path.exists('mini_data/Validation/pig_label'):
    os.mkdir('mini_data/Validation/pig_label')

# %%
import shutil

# 돼지 Data 이동
for image, label in tqdm(zip(train_pig_image, train_pig_label)):
    if image in X_train:
        image_dst = '/content/mini_data/Training/pig_image'
        label_dst = '/content/mini_data/Training/pig_label'
        shutil.copy(image, image_dst)
        shutil.copy(label, label_dst)
    if image in X_valid:
        image_dst = '/content/mini_data/Validation/pig_image'
        label_dst = '/content/mini_data/Validation/pig_label'
        shutil.copy(image, image_dst)
        shutil.copy(label, label_dst)

# 소 Data 이동
for image, label in tqdm(zip(train_cow_image, train_cow_label)):
    if image in X_train:
        image_dst = '/content/mini_data/Training/cow_image'
        label_dst = '/content/mini_data/Training/cow_label'
        shutil.copy(image, image_dst)
        shutil.copy(label, label_dst)
    if image in X_valid:
        image_dst = '/content/mini_data/Validation/cow_image'
        label_dst = '/content/mini_data/Validation/cow_label'
        shutil.copy(image, image_dst)
        shutil.copy(label, label_dst)
# Out:
# 4303it [00:11, 381.67it/s]
# 12152it [01:04, 187.29it/s]

# %%
train_pig_image_sub = glob('/content/mini_data/Training/pig_image/*.jpg')
train_cow_image_sub = glob('/content/mini_data/Training/cow_image/*.jpg')
train_pig_label_sub = glob('/content/mini_data/Training/pig_label/*.json')
train_cow_label_sub = glob('/content/mini_data/Training/cow_label/*.json')

valid_pig_image_sub = glob('/content/mini_data/Validation/pig_image/*.jpg')
valid_cow_image_sub = glob('/content/mini_data/Validation/cow_image/*.jpg')
valid_pig_label_sub = glob('/content/mini_data/Validation/pig_label/*.json')
valid_cow_label_sub = glob('/content/mini_data/Validation/cow_label/*.json')

train_pig_label_sub.sort()
train_pig_image_sub.sort()
train_cow_label_sub.sort()
train_cow_image_sub.sort()

valid_pig_label_sub.sort()
valid_pig_image_sub.sort()
valid_cow_label_sub.sort()
valid_cow_image_sub.sort()

# %%
print('Train Pig Data의 개수:', len(train_pig_image_sub))
print('Train Pig Data의 개수:', len(train_pig_label_sub))

print('Valid Pig Data의 개수:', len(valid_pig_image_sub))
print('Valid Pig Data의 개수:', len(valid_pig_label_sub))

print('Train Cow Data의 개수', len(train_cow_image_sub))
print('Train Cow Data의 개수', len(train_cow_label_sub))

print('Valid Cow Data의 개수', len(valid_cow_image_sub))
print('Valid Cow Data의 개수', len(valid_cow_label_sub))
# Out:
# Train Pig Data의 개수: 1721
# Train Pig Data의 개수: 1721
# Valid Pig Data의 개수: 861
# Valid Pig Data의 개수: 861
# Train Cow Data의 개수 4861
# Train Cow Data의 개수 4861
# Valid Cow Data의 개수 2430
# Valid Cow Data의 개수 2430

# %%
# Data를 GoogleDrive tar형태로 압축
# !tar -cvf /content/drive/MyDrive/AI_Factory/data/Train_Dataset_mini.tar /content/mini_data/Training
# !tar -cvf /content/drive/MyDrive/AI_Factory/data/Valid_Dataset_mini.tar /content/mini_data/Validation
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_010486.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_009198.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_013289.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_011089.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_002452.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_003887.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_012032.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_013598.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_009150.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_000011.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_010693.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_000646.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_003115.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_000984.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_008413.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_001740.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_009393.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_005377.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_010912.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_011952.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_008378.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_012710.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_004416.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_011168.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_013008.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_002945.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_008650.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_011643.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_013245.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_001067.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_005269.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_004686.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_008159.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_000991.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_009883.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_002932.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_010581.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_008389.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_011598.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_005205.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_009799.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_000548.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_005385.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_000152.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_004176.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_009069.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_012254.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_005243.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_003986.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_004875.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_011477.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_002634.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_003400.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_012162.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_012928.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_004262.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_011460.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_008542.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_004956.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_002681.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_011668.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_001769.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_005877.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_004073.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_000080.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_003897.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_005625.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_010011.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_000238.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_003844.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_001191.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_005888.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_011842.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_010219.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_008036.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_000908.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_003940.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_011216.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_009767.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_009886.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_003808.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_008320.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_001843.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_009014.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_005197.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_011421.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_004553.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_013430.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_011976.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_008346.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_000624.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_011844.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_013186.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_008718.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_009588.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_002367.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_004521.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_013350.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_002174.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_002397.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_004267.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_008812.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_007869.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_000804.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_001028.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_003086.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_002392.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_003681.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_002769.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_010522.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_011162.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_010037.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_011914.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_011554.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_012404.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_000101.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_005059.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_005929.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_002444.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_001890.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_003774.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_011625.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_010633.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_010138.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_008277.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_012494.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_002796.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_013435.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_010375.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_005293.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_012057.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_005113.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_002712.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_009030.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_011978.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_004641.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_008233.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_001835.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_003969.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_002883.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_000591.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_005585.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_000066.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_003961.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_009649.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_010803.json
# /content/mini_data/Validation/cow_label/livestock_cow_bbox_